# %%
Q1. Explain with an example each when to use a for loop and a while loop.

ans :
The for loop is used when the number of iterations is already known.

A "while" loop is used when the number of iterations is unknown. The statement repeats itself till the boolean value becomes false.

Example: For loop

n = [1, 2, 3]  
for i in n: 
    print(i)
    
Example: While loop

i = 1  
while i < 6:  
    print(i)
    i =i + 1

# %%
Q2. Write a python program to print the sum and product of the first 10 natural numbers using for
and while loop.

ans:
the sum  of the first 10 natural numbers using for loop

addition = 0

for i in range(1,11):
    addition = addition + i

addition

outcome - 55

The product  of the first 10 natural numbers using for loop

product = 1

for i in range(1,11):
    product = product + i

product

outcome - 3628800

The sum  of the first 10 natural numbers using while loop

addition1 = 0
i = 1 

while i <= 10:
    addition1 = addition1 + i
    i =i + 1
addition1

outcome- 55

The product  of the first 10 natural numbers using while loop


product1 = 1

i = 1

while i <= 10:
    product1 = product1 * i
    i += 1
product1

outcome - 3628800

# %%
Q3. Create a python program to compute the electricity bill for a household.
The per-unit charges in rupees are as follows: For the first 100 units, the user will be charged Rs. 4.5 per
unit, for the next 100 units, the user will be charged Rs. 6 per unit, and for the next 100 units, the user will
be charged Rs. 10 per unit, After 300 units and above the user will be charged Rs. 20 per unit.
You are required to take the units of electricity consumed in a month from the user as input.
Your program must pass this test case: when the unit of electricity consumed by the user in a month is
310, the total electricity bill should be 2250.



units = int(input('enter consumed electricity in units'))

if units <= 100:
    electricity_bill = unit * 4.5
elif units <= 200:
    electricity_bill = 100 * 4.5 + (units - 100) * 6
elif units <= 300:
    electricity_bill = 100 * 4.5 + 100 * 6 + (units - 200) * 10
else:
    electricity_bill = 100 * 4.5 + 100 * 6 + 100 * 10 + (units-300)*20
    
print(electricity_bill)
    
output - 2250.0

# %%
Q.5 Write a program to filter count vowels in the below-given string.
string = "I want to become a data scientist"

ans:
string = 'i want to become a datascientist'

count = 0 

for i in string:
    if i in ['a','e','i','o','u']:
        count += 1
print(count)


Outcome- 12

# %%
Q.4 Create a list of numbers from 1 to 100. Use for loop and while loop to calculate the cube of each
  number and if the cube of that number is divisible by 4 or 5 then append that number in a list and print
 that list.

# %%
# using while loop
l = list(range(1,101))

l1 = []

x = 1

y = 0

while x <= len(l):
    
    y = x*x*x
    
    x = x+1
   # print(y)
    if y % 4 == 0 and y % 5 == 0 :
        l1.append(y)
print(l1)
[1000, 8000, 27000, 64000, 125000, 216000, 343000, 512000, 729000, 1000000]

# using for loop
l = list(range(1,101))

l0 = []

n = 1
for i in l :
    n = i*i*i
   # print (n)
    if n % 4 == 0 and n % 5 == 0 :
        l0.append(n)
print(l0)
[1000, 8000, 27000, 64000, 125000, 216000, 343000, 512000, 729000, 1000000]
